# %% [markdown]
# Adapted from https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Conv2D,MaxPool2D,Flatten,Dropout,LSTM
from tensorflow.keras.utils import plot_model

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix,mean_squared_error
from sklearn.preprocessing import MinMaxScaler

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
np.random.seed(11)

# %%
# load the dataset
path = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv'
df = pd.read_csv(path, header=0, index_col=0, squeeze=True)

# %%
df.head()
# Out:
# Month
# 1949-01    112
# 1949-02    118
# 1949-03    132
# 1949-04    129
# 1949-05    121
# Name: Passengers, dtype: int64

# %%
# retrieve the values
sequence = df.values.astype('float32')

# %%
plt.plot(sequence)

# %%
def split_sequence(sequence,n_steps):
## split 1d sequence into samples
    x,y = [],[]
    for i in range(len(sequence)-n_steps-1):
        j = i+n_steps
        x.append(sequence[i:j])
        y.append(sequence[j])
        
    return np.array(x),np.array(y)

# %%
n_steps = 4
x,y = split_sequence(sequence,n_steps)

# %%
sequence[0:10]
# Out:
# array([112., 118., 132., 129., 121., 135., 148., 148., 136., 119.],
#       dtype=float32)

# %%
x[:10]
# Out:
# array([[112., 118., 132., 129.],
#        [118., 132., 129., 121.],
#        [132., 129., 121., 135.],
#        [129., 121., 135., 148.],
#        [121., 135., 148., 148.],
#        [135., 148., 148., 136.],
#        [148., 148., 136., 119.],
#        [148., 136., 119., 104.],
#        [136., 119., 104., 118.],
#        [119., 104., 118., 115.]], dtype=float32)

# %%
y[:10]
# Out:
# array([121., 135., 148., 148., 136., 119., 104., 118., 115., 126.],
#       dtype=float32)

# %%
# split into train and test sets
test_size = 0.4

n_samples = x.shape[0]
n_train = int((1-test_size)*n_samples)

x_train, y_train = x[:n_train],y[:n_train] 
x_test, y_test = x[n_train:],y[n_train:]

# %%
# normalize the dataset
#scaler = MinMaxScaler(feature_range=(0, 1))
#values = scaler.fit_transform(values.reshape(-1,1))

# %%
# reshape into [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))

# %%
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %%
# define model
model = Sequential()
model.add(LSTM(32, activation='relu', kernel_initializer='he_normal', input_shape=(n_steps,1)))
model.add(Dense(16, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 32)                4352
# _________________________________________________________________
# dense (Dense)                (None, 16)                528
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 4,897
# Trainable params: 4,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, 'model_RNN.png', show_shapes=True)

# %%
# compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
history = model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.2,verbose=2)
# Out:
# Train on 66 samples, validate on 17 samples
# Epoch 1/100
# 66/66 - 1s - loss: 115180.1133 - mae: 308.5840 - val_loss: 200519.3906 - val_mae: 401.9680
# Epoch 2/100
# 66/66 - 0s - loss: 81446.9321 - mae: 255.8339 - val_loss: 120469.2578 - val_mae: 315.6118
# Epoch 3/100
# 66/66 - 0s - loss: 64012.2232 - mae: 224.9839 - val_loss: 97108.7344 - val_mae: 281.2918
# Epoch 4/100
# 66/66 - 0s - loss: 53115.5540 - mae: 201.5738 - val_loss: 73628.7812 - val_mae: 239.1278
# Epoch 5/100
# 66/66 - 0s - loss: 37402.2955 - mae: 166.5835 - val_loss: 44309.6328 - val_mae: 197.5300
# Epoch 6/100
# 66/66 - 0s - loss: 26498.3855 - mae: 141.7990 - val_loss: 60251.7148 - val_mae: 208.5658
# Epoch 7/100
# 66/66 - 0s - loss: 23017.0748 - mae: 128.8724 - val_loss: 41703.2344 - val_mae: 172.0601
# Epoch 79/100
# 66/66 - 0s - loss: 505.6192 - mae: 16.5364 - val_loss: 794.7166 - val_mae: 22.5022
# Epoch 80/100
# 66/66 - 0s - loss: 501.3286 - mae: 16.4386 - val_loss: 803.1224 - val_mae: 22.5249
# Epoch 81/100
# 66/66 - 0s - loss: 497.2668 - mae: 16.3952 - val_loss: 802.4355 - val_mae: 22.4836
# Epoch 82/100
# 66/66 - 0s - loss: 491.0943 - mae: 16.2947 - val_loss: 786.0776 - val_mae: 22.4341
# Epoch 83/100
# 66/66 - 0s - loss: 483.2186 - mae: 16.1528 - val_loss: 764.8478 - val_mae: 22.3656
# Epoch 84/100
# 66/66 - 0s - loss: 474.1861 - mae: 15.9859 - val_loss: 743.3641 - val_mae: 22.2250
# Epoch 85/100
# 66/66 - 0s - loss: 467.9079 - mae: 15.8505 - val_loss: 732.6760 - val_mae: 22.0238
# Epoch 86/100
# 66/66 - 0s - loss: 461.5652 - mae: 15.7251 - val_loss: 723.5468 - val_mae: 21.8547
# Epoch 87/100
# 66/66 - 0s - loss: 456.8272 - mae: 15.6308 - val_loss: 708.9557 - val_mae: 21.7020
# Epoch 88/100
# 66/66 - 0s - loss: 451.3198 - mae: 15.5166 - val_loss: 690.6586 - val_mae: 21.5610
# Epoch 89/100
# 66/66 - 0s - loss: 444.2439 - mae: 15.3601 - val_loss: 676.5570 - val_mae: 21.4228
# Epoch 90/100
# 66/66 - 0s - loss: 439.5710 - mae: 15.2688 - val_loss: 669.0011 - val_mae: 21.2416
# Epoch 91/100
# 66/66 - 0s - loss: 434.9653 - mae: 15.1897 - val_loss: 674.1096 - val_mae: 20.9646
# Epoch 92/100
# 66/66 - 0s - loss: 433.8242 - mae: 15.1609 - val_loss: 683.7207 - val_mae: 20.7157
# Epoch 93/100
# 66/66 - 0s - loss: 431.3857 - mae: 15.1491 - val_loss: 680.6357 - val_mae: 20.6053
# Epoch 94/100
# 66/66 - 0s - loss: 427.4708 - mae: 15.0712 - val_loss: 668.7946 - val_mae: 20.5506
# Epoch 95/100
# 66/66 - 0s - loss: 423.4715 - mae: 15.0315 - val_loss: 654.6790 - val_mae: 20.5064
# Epoch 96/100
# 66/66 - 0s - loss: 419.1302 - mae: 14.9447 - val_loss: 644.4240 - val_mae: 20.4823
# Epoch 97/100
# 66/66 - 0s - loss: 416.1743 - mae: 14.8829 - val_loss: 630.4124 - val_mae: 20.5271
# Epoch 98/100
# 66/66 - 0s - loss: 414.0836 - mae: 14.8575 - val_loss: 629.2231 - val_mae: 20.6984
# Epoch 99/100
# 66/66 - 0s - loss: 411.4995 - mae: 14.8353 - val_loss: 649.1727 - val_mae: 21.0516
# Epoch 100/100
# 66/66 - 0s - loss: 408.5678 - mae: 14.8166 - val_loss: 668.5342 - val_mae: 21.2520

# %%
# Learning curves
acc = history.history['mae']
val_acc = history.history['val_mae']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='upper right')
plt.ylabel('Accuracy')
#plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
#plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# make predictions
y_pred = model.predict(x_test)

# %%
plt.plot(y_test,label='actual')
plt.plot(y_pred,label='predicted')
plt.legend()
