# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Conv2D,MaxPool2D,Flatten,Dropout,LSTM
from tensorflow.keras.utils import plot_model

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
s = np.loadtxt('Delayed_SYNAPTIC.txt')

# %%
# exclude the first column (index) and unstable initial time points
s = s[10:,1:]

# %%
nx,ny = 3,4
nfig = nx*ny
fig, ax = plt.subplots(ny,nx,figsize=(nx*3.5,ny*2.8))

ifig = 0
for i in range(nx):
    for j in range(ny):
        ifig += 1
        #ax[j,i].set_title('S%s'%(ifig))
        ax[j,i].plot(s[:500,ifig-1])
        ax[j,i].set_xlabel('time (s)')
        ax[j,i].set_ylabel('S%s'%ifig)
        
plt.tight_layout(h_pad=1, w_pad=1.5)
#plt.savefig('fig1.pdf', format='pdf', dpi=100)

# %%
s.shape
# Out:
# (29990, 12)

# %%
# predict s12 from others
x = s[:,:11]
y = s[:,11]

# %%
x.shape
# Out:
# (29990, 11)

# %%
# reshape into [samples, features,1]
x = x.reshape((x.shape[0], x.shape[1], 1))

# %%
x.shape

# %%
n_train = 2000
x_train = x[:n_train]
y_train = y[:n_train]

x_test = x[n_train:]
y_test = y[n_train:]

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (1600, 11)

# %%
y_train.shape
# Out:
# (1600,)

# %%
# define model
model = Sequential()
model.add(LSTM(100, activation='relu', kernel_initializer='he_normal', input_shape=(n_steps,1)))
model.add(Dense(50, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1))

# %%
model.summary()

# %%
# compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
# fit the model
history = model.fit(x_train, y_train, epochs=350, batch_size=32, verbose=2, validation_data=(x_val, y_val))b

# %%
yhat = model.predict(x_test)
