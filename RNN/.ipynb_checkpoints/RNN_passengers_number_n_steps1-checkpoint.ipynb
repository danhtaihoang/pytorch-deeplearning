# %% [markdown]
# Adapted from https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Conv2D,MaxPool2D,Flatten,Dropout,LSTM
from tensorflow.keras.utils import plot_model

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix,mean_squared_error
from sklearn.preprocessing import MinMaxScaler

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
np.random.seed(11)

# %%
# load the dataset
path = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv'
df = pd.read_csv(path, header=0, index_col=0, squeeze=True)

# %%
df.head()
# Out:
# Month
# 1949-01    112
# 1949-02    118
# 1949-03    132
# 1949-04    129
# 1949-05    121
# Name: Passengers, dtype: int64

# %%
# retrieve the values
sequence = df.values.astype('float32')

# %%
plt.plot(sequence)

# %%
def split_sequence(sequence,n_steps):
## split 1d sequence into samples
    x,y = [],[]
    for i in range(len(sequence)-n_steps-1):
        j = i+n_steps
        x.append(sequence[i:j])
        y.append(sequence[j])
        
    return np.array(x),np.array(y)

# %%
n_steps = 1
x,y = split_sequence(sequence,n_steps)

# %%
sequence[0:10]
# Out:
# array([112., 118., 132., 129., 121., 135., 148., 148., 136., 119.],
#       dtype=float32)

# %%
x[:10]
# Out:
# array([[112.],
#        [118.],
#        [132.],
#        [129.],
#        [121.],
#        [135.],
#        [148.],
#        [148.],
#        [136.],
#        [119.]], dtype=float32)

# %%
y[:10]
# Out:
# array([118., 132., 129., 121., 135., 148., 148., 136., 119., 104.],
#       dtype=float32)

# %%
# split into train and test sets
test_size = 0.4

n_samples = x.shape[0]
n_train = int((1-test_size)*n_samples)

x_train, y_train = x[:n_train],y[:n_train] 
x_test, y_test = x[n_train:],y[n_train:]

# %%
# normalize the dataset
#scaler = MinMaxScaler(feature_range=(0, 1))
#values = scaler.fit_transform(values.reshape(-1,1))

# %%
# reshape into [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))

# %%
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %%
# define model
model = Sequential()
model.add(LSTM(32, activation='relu', kernel_initializer='he_normal', input_shape=(n_steps,1)))
model.add(Dense(16, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 32)                4352
# _________________________________________________________________
# dense (Dense)                (None, 16)                528
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 4,897
# Trainable params: 4,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, 'model_RNN.png', show_shapes=True)

# %%
# compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
history = model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.2,verbose=2)
# Out:
# Train on 68 samples, validate on 17 samples
# Epoch 1/100
# 68/68 - 1s - loss: 10973.7297 - mae: 100.7800 - val_loss: 19320.3340 - val_mae: 135.9040
# Epoch 2/100
# 68/68 - 0s - loss: 8814.0344 - mae: 90.0183 - val_loss: 15204.4551 - val_mae: 120.0042
# Epoch 3/100
# 68/68 - 0s - loss: 6917.2952 - mae: 79.4750 - val_loss: 11683.4375 - val_mae: 104.4722
# Epoch 4/100
# 68/68 - 0s - loss: 5320.6004 - mae: 69.1333 - val_loss: 8746.3701 - val_mae: 89.4418
# Epoch 5/100
# 68/68 - 0s - loss: 3936.6979 - mae: 59.1186 - val_loss: 6337.7324 - val_mae: 74.8513
# Epoch 6/100
# 68/68 - 0s - loss: 2835.0020 - mae: 49.3908 - val_loss: 4378.6582 - val_mae: 60.3741
# Epoch 7/100
# 68/68 - 0s - loss: 1964.1698 - mae: 39.7681 - val_loss: 2914.9124 - val_mae: 46.6189
# Epoch 8/100
# 68/68 - 0s - loss: 1295.0553 - mae: 30.7279 - val_loss: 1913.2996 - val_mae: 34.4556
# Epoch 9/100
# 68/68 - 0s - loss: 851.3430 - mae: 23.6367 - val_loss: 1330.8391 - val_mae: 29.2250
# Epoch 10/100
# 68/68 - 0s - loss: 593.9854 - mae: 19.5001 - val_loss: 1007.8148 - val_mae: 25.7734
# Epoch 11/100
# 68/68 - 0s - loss: 442.5989 - mae: 17.2123 - val_loss: 864.4699 - val_mae: 24.4497
# Epoch 12/100
# 68/68 - 0s - loss: 374.4065 - mae: 15.8291 - val_loss: 833.8486 - val_mae: 24.4622
# Epoch 13/100
# 68/68 - 0s - loss: 347.7482 - mae: 15.1426 - val_loss: 860.3869 - val_mae: 25.1986
# Epoch 14/100
# 68/68 - 0s - loss: 354.3052 - mae: 15.3110 - val_loss: 903.0950 - val_mae: 26.1608
# Epoch 15/100
# 68/68 - 0s - loss: 369.5035 - mae: 15.5595 - val_loss: 936.7515 - val_mae: 26.7994
# Epoch 16/100
# 68/68 - 0s - loss: 378.9578 - mae: 15.7040 - val_loss: 950.2000 - val_mae: 27.0245
# Epoch 17/100
# 68/68 - 0s - loss: 382.9739 - mae: 15.7872 - val_loss: 948.0524 - val_mae: 26.9895
# Epoch 18/100
# 68/68 - 0s - loss: 381.7744 - mae: 15.7549 - val_loss: 939.4915 - val_mae: 26.8463
# Epoch 19/100
# 68/68 - 0s - loss: 378.9112 - mae: 15.6959 - val_loss: 930.4818 - val_mae: 26.6893
# Epoch 20/100
# 68/68 - 0s - loss: 374.9036 - mae: 15.6256 - val_loss: 917.8582 - val_mae: 26.4565
# Epoch 21/100
# 68/68 - 0s - loss: 370.1384 - mae: 15.5419 - val_loss: 902.1774 - val_mae: 26.1415
# Epoch 22/100
# 68/68 - 0s - loss: 366.5076 - mae: 15.5093 - val_loss: 889.3619 - val_mae: 25.8560
# Epoch 23/100
# 68/68 - 0s - loss: 361.5488 - mae: 15.4357 - val_loss: 880.5153 - val_mae: 25.6393
# Epoch 24/100
# 68/68 - 0s - loss: 358.0768 - mae: 15.4083 - val_loss: 867.4763 - val_mae: 25.3479
# Epoch 25/100
# 68/68 - 0s - loss: 355.2862 - mae: 15.3631 - val_loss: 857.1936 - val_mae: 25.1249
# Epoch 26/100
# 68/68 - 0s - loss: 352.8429 - mae: 15.3162 - val_loss: 849.9482 - val_mae: 24.9365
# Epoch 27/100
# 68/68 - 0s - loss: 351.3100 - mae: 15.2914 - val_loss: 846.4469 - val_mae: 24.8304
# Epoch 28/100
# 68/68 - 0s - loss: 350.8942 - mae: 15.2833 - val_loss: 846.2061 - val_mae: 24.8226
# Epoch 29/100
# 68/68 - 0s - loss: 350.1210 - mae: 15.2784 - val_loss: 842.1985 - val_mae: 24.6797
# Epoch 30/100
# 68/68 - 0s - loss: 349.3187 - mae: 15.2653 - val_loss: 839.3494 - val_mae: 24.5705
# Epoch 31/100
# 68/68 - 0s - loss: 349.3631 - mae: 15.2740 - val_loss: 836.8572 - val_mae: 24.5014
# Epoch 32/100
# Epoch 56/100
# 68/68 - 0s - loss: 339.0791 - mae: 14.9372 - val_loss: 828.4799 - val_mae: 24.3573
# Epoch 57/100
# 68/68 - 0s - loss: 338.8075 - mae: 14.9300 - val_loss: 830.8231 - val_mae: 24.3935
# Epoch 58/100
# 68/68 - 0s - loss: 343.2286 - mae: 14.9612 - val_loss: 838.7906 - val_mae: 24.6814
# Epoch 59/100
# 68/68 - 0s - loss: 346.5872 - mae: 15.0240 - val_loss: 840.2788 - val_mae: 24.7206
# Epoch 60/100
# 68/68 - 0s - loss: 346.1810 - mae: 14.9955 - val_loss: 834.5720 - val_mae: 24.4899
# Epoch 61/100
# 68/68 - 0s - loss: 341.5299 - mae: 14.9386 - val_loss: 830.4102 - val_mae: 24.3738
# Epoch 62/100
# 68/68 - 0s - loss: 340.6038 - mae: 14.9283 - val_loss: 829.2093 - val_mae: 24.3805
# Epoch 63/100
# 68/68 - 0s - loss: 340.4437 - mae: 14.9863 - val_loss: 830.0078 - val_mae: 24.3831
# Epoch 64/100
# 68/68 - 0s - loss: 340.8201 - mae: 15.0109 - val_loss: 830.3044 - val_mae: 24.3809
# Epoch 65/100
# 68/68 - 0s - loss: 340.7241 - mae: 15.0124 - val_loss: 829.4767 - val_mae: 24.3739
# Epoch 66/100
# 68/68 - 0s - loss: 340.8560 - mae: 14.9988 - val_loss: 828.8746 - val_mae: 24.3635
# Epoch 67/100
# 68/68 - 0s - loss: 341.1345 - mae: 14.9914 - val_loss: 829.4003 - val_mae: 24.3612
# Epoch 68/100
# 68/68 - 0s - loss: 339.7841 - mae: 14.9604 - val_loss: 828.2212 - val_mae: 24.3535
# Epoch 69/100
# 68/68 - 0s - loss: 339.3324 - mae: 14.9259 - val_loss: 827.4956 - val_mae: 24.3455
# Epoch 70/100
# 68/68 - 0s - loss: 338.5951 - mae: 14.9092 - val_loss: 826.6580 - val_mae: 24.3281
# Epoch 71/100
# 68/68 - 0s - loss: 338.7074 - mae: 14.8777 - val_loss: 825.9523 - val_mae: 24.3134
# Epoch 72/100
# 68/68 - 0s - loss: 338.4730 - mae: 14.8924 - val_loss: 826.8994 - val_mae: 24.3153
# Epoch 73/100
# 68/68 - 0s - loss: 338.0039 - mae: 14.8696 - val_loss: 826.4686 - val_mae: 24.3037
# Epoch 74/100
# 68/68 - 0s - loss: 337.5492 - mae: 14.8456 - val_loss: 825.3809 - val_mae: 24.2924
# Epoch 75/100
# 68/68 - 0s - loss: 337.8534 - mae: 14.8494 - val_loss: 823.4736 - val_mae: 24.2671
# Epoch 76/100
# 68/68 - 0s - loss: 337.3634 - mae: 14.7998 - val_loss: 821.6536 - val_mae: 24.2302
# Epoch 77/100
# 68/68 - 0s - loss: 338.7152 - mae: 14.8456 - val_loss: 819.8250 - val_mae: 24.1613
# Epoch 78/100
# 68/68 - 0s - loss: 346.0801 - mae: 14.9418 - val_loss: 818.9664 - val_mae: 24.1354
# Epoch 79/100
# 68/68 - 0s - loss: 343.7504 - mae: 14.9414 - val_loss: 819.8268 - val_mae: 24.1964
# Epoch 80/100
# 68/68 - 0s - loss: 339.2092 - mae: 14.8645 - val_loss: 824.1357 - val_mae: 24.2524
# Epoch 81/100
# 68/68 - 0s - loss: 338.1568 - mae: 14.8474 - val_loss: 827.9810 - val_mae: 24.2794
# Epoch 82/100
# 68/68 - 0s - loss: 337.5703 - mae: 14.8695 - val_loss: 829.7632 - val_mae: 24.2961
# Epoch 83/100
# 68/68 - 0s - loss: 338.9033 - mae: 14.9228 - val_loss: 830.8473 - val_mae: 24.3100
# Epoch 84/100
# 68/68 - 0s - loss: 338.8369 - mae: 14.9575 - val_loss: 834.8873 - val_mae: 24.3322
# Epoch 85/100
# 68/68 - 0s - loss: 341.7220 - mae: 15.0784 - val_loss: 837.8480 - val_mae: 24.3445
# Epoch 86/100
# 68/68 - 0s - loss: 342.9002 - mae: 15.1042 - val_loss: 834.2017 - val_mae: 24.3408
# Epoch 87/100
# 68/68 - 0s - loss: 340.1178 - mae: 15.0076 - val_loss: 828.6135 - val_mae: 24.3276
# Epoch 88/100
# 68/68 - 0s - loss: 338.4205 - mae: 14.8774 - val_loss: 825.3373 - val_mae: 24.3025
# Epoch 89/100
# 68/68 - 0s - loss: 340.3732 - mae: 14.8751 - val_loss: 827.6369 - val_mae: 24.3229
# Epoch 90/100
# 68/68 - 0s - loss: 341.8878 - mae: 14.9097 - val_loss: 828.4288 - val_mae: 24.3389
# Epoch 91/100
# 68/68 - 0s - loss: 341.3231 - mae: 14.8787 - val_loss: 826.9158 - val_mae: 24.3241
# Epoch 92/100
# 68/68 - 0s - loss: 338.1693 - mae: 14.8630 - val_loss: 827.2297 - val_mae: 24.3414
# Epoch 93/100
# 68/68 - 0s - loss: 339.5036 - mae: 14.9368 - val_loss: 828.5688 - val_mae: 24.3502
# Epoch 94/100
# 68/68 - 0s - loss: 339.1640 - mae: 14.9319 - val_loss: 828.4419 - val_mae: 24.3476
# Epoch 95/100
# 68/68 - 0s - loss: 340.4620 - mae: 14.9621 - val_loss: 829.8578 - val_mae: 24.3498
# Epoch 96/100
# 68/68 - 0s - loss: 339.6283 - mae: 14.9720 - val_loss: 829.3203 - val_mae: 24.3439
# Epoch 97/100
# 68/68 - 0s - loss: 338.9197 - mae: 14.9306 - val_loss: 827.5182 - val_mae: 24.3337
# Epoch 98/100
# 68/68 - 0s - loss: 338.3692 - mae: 14.9111 - val_loss: 826.4006 - val_mae: 24.3230
# Epoch 99/100
# 68/68 - 0s - loss: 338.1544 - mae: 14.8745 - val_loss: 826.6085 - val_mae: 24.3235
# Epoch 100/100
# 68/68 - 0s - loss: 338.2415 - mae: 14.8822 - val_loss: 827.5883 - val_mae: 24.3272

# %%
# Learning curves
acc = history.history['mae']
val_acc = history.history['val_mae']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='upper right')
plt.ylabel('Accuracy')
#plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
#plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# make predictions
y_pred = model.predict(x_test)

# %%
plt.plot(y_test,label='actual')
plt.plot(y_pred,label='predicted')
plt.legend()
