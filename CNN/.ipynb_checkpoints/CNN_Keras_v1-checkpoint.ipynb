# %%
# Convolutional Neural Network
import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Conv2D,MaxPool2D,Flatten,Dropout

from tensorflow.keras.datasets.mnist import load_data
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from tensorflow.keras.utils import plot_model
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# load data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
# reshape data to have a single channel
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], x_test.shape[2], 1))

# %%
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
x_test.shape
# Out:
# (10000, 28, 28, 1)

# %%
# determine the shape of the input images
input_shape = x_train.shape[1:]
print(input_shape)
# Out:
# (28, 28, 1)

# %%
# determine the number of classes
n_classes = len(np.unique(y_train))
print(n_classes)
# Out:
# 10

# %%
# normalize pixel values
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %%
# define model
model = Sequential()
model.add(Conv2D(32, (3,3), activation='relu', kernel_initializer='he_uniform', input_shape=input_shape))
model.add(MaxPool2D((2, 2)))
model.add(Flatten())
model.add(Dense(100, activation='relu', kernel_initializer='he_uniform'))
model.add(Dropout(0.5))
model.add(Dense(n_classes, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 5408)              0
# _________________________________________________________________
# dense (Dense)                (None, 100)               540900
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 542,230
# Trainable params: 542,230
# Non-trainable params: 0
# _________________________________________________________________

# %%
# plot the model
plot_model(model, 'model.png', show_shapes=True)

# %%
# define loss and optimizer
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# fit the model
history = model.fit(x_train, y_train, epochs=20, batch_size=128, verbose=1,validation_split=0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 11s 238us/sample - loss: 0.3717 - accuracy: 0.8863 - val_loss: 0.1005 - val_accuracy: 0.9722
# Epoch 2/20
# 48000/48000 [==============================] - 10s 206us/sample - loss: 0.1567 - accuracy: 0.9539 - val_loss: 0.0703 - val_accuracy: 0.9781
# Epoch 3/20
# 48000/48000 [==============================] - 10s 200us/sample - loss: 0.1130 - accuracy: 0.9665 - val_loss: 0.0592 - val_accuracy: 0.9823
# Epoch 4/20
# 48000/48000 [==============================] - 10s 212us/sample - loss: 0.0954 - accuracy: 0.9702 - val_loss: 0.0572 - val_accuracy: 0.9835
# Epoch 5/20
# 48000/48000 [==============================] - 8s 165us/sample - loss: 0.0818 - accuracy: 0.9755 - val_loss: 0.0545 - val_accuracy: 0.9837
# Epoch 6/20
# 48000/48000 [==============================] - 7s 140us/sample - loss: 0.0698 - accuracy: 0.9784 - val_loss: 0.0544 - val_accuracy: 0.9838
# Epoch 7/20
# 48000/48000 [==============================] - 11s 221us/sample - loss: 0.0639 - accuracy: 0.9802 - val_loss: 0.0539 - val_accuracy: 0.9848
# Epoch 8/20
# 48000/48000 [==============================] - 13s 261us/sample - loss: 0.0580 - accuracy: 0.9818 - val_loss: 0.0527 - val_accuracy: 0.9847
# Epoch 9/20
# 48000/48000 [==============================] - 12s 252us/sample - loss: 0.0532 - accuracy: 0.9825 - val_loss: 0.0552 - val_accuracy: 0.9853
# Epoch 10/20
# 48000/48000 [==============================] - 13s 270us/sample - loss: 0.0515 - accuracy: 0.9834 - val_loss: 0.0504 - val_accuracy: 0.9867
# Epoch 11/20
# 48000/48000 [==============================] - 14s 292us/sample - loss: 0.0436 - accuracy: 0.9855 - val_loss: 0.0511 - val_accuracy: 0.9867
# Epoch 12/20
# 48000/48000 [==============================] - 13s 262us/sample - loss: 0.0403 - accuracy: 0.9867 - val_loss: 0.0510 - val_accuracy: 0.9853
# Epoch 13/20
# 48000/48000 [==============================] - 15s 313us/sample - loss: 0.0375 - accuracy: 0.9876 - val_loss: 0.0496 - val_accuracy: 0.9864
# Epoch 14/20
# 48000/48000 [==============================] - 14s 291us/sample - loss: 0.0369 - accuracy: 0.9880 - val_loss: 0.0513 - val_accuracy: 0.9856
# Epoch 15/20
# 48000/48000 [==============================] - 14s 295us/sample - loss: 0.0334 - accuracy: 0.9892 - val_loss: 0.0559 - val_accuracy: 0.9860
# Epoch 16/20
# 48000/48000 [==============================] - 15s 320us/sample - loss: 0.0331 - accuracy: 0.9891 - val_loss: 0.0558 - val_accuracy: 0.9872
# Epoch 17/20
# 48000/48000 [==============================] - 14s 296us/sample - loss: 0.0283 - accuracy: 0.9911 - val_loss: 0.0553 - val_accuracy: 0.9861
# Epoch 18/20
# 48000/48000 [==============================] - 15s 315us/sample - loss: 0.0281 - accuracy: 0.9906 - val_loss: 0.0574 - val_accuracy: 0.9855
# Epoch 19/20
# 48000/48000 [==============================] - 15s 309us/sample - loss: 0.0262 - accuracy: 0.9912 - val_loss: 0.0558 - val_accuracy: 0.9866
# Epoch 20/20
# 48000/48000 [==============================] - 17s 356us/sample - loss: 0.0256 - accuracy: 0.9911 - val_loss: 0.0557 - val_accuracy: 0.9868

# %%
# Learning curves
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
#plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# evaluate the model
loss, acc = model.evaluate(x_test, y_test, verbose=0)
print('Accuracy: %.3f' % acc)
# Out:
# Accuracy: 0.986

# %%
# make a prediction
itest = 1
yhat = model.predict([[x_test[itest]]])
print('Predicted: class=%d' % np.argmax(yhat))
# Out:
# Predicted: class=2

# %%
print('Actual: class=%d' % y_test[itest])
# Out:
# Actual: class=2
